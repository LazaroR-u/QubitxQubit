# %% [markdown]
# <a href="https://colab.research.google.com/github/LazaroR-u/QubitxQubit/blob/main/Complexity_of_algorithms_QXQ_YLC_Week_15_Lab_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lab 14: Complexity of Algorithms**
# ---
#
# ### **Description**
# Today, we will work with two of the most famous classical search algorithms: linear and binary search. We will implement and analyze their performance.
#
#
#
# <br>
#
# ### **Structure**
# ### **Structure**
# **Part 1**: [Linear Search](#p1)
#
# **Part 2**: [Binary Search](#p2)
#
#
# <br>
#
# ### **Learning Objectives**
# By the end of this lab, you will:
# * Recognize how to compare algorithms using big-O notation.
# * Recognize the limits of classical search algorithms for unordered lists.
#
#
# <br>
#
# ### **Resources**
# * [Linear Search as a Dance](http://www.youtube.com/watch?v=-PuqKbu9K3U)
#
# * [Binary Search as a Dance](http://www.youtube.com/watch?v=wz7XgKowJIg)
#
#
# <br>
#
# **Before starting, run the code below to import all necessary functions and libraries.**

# %%
# @title
# Importing other python libraries
import random
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# <a name="p1"></a>
#
# ---
# ## **Part 1: Linear Search**
# ---
#
# In this section, we will implement and analyze the linear search algorithm.

# %% [markdown]
# #### **Problem #1.1**
#
# **Together**, let's run the code below to implement linear search for a list of numbers. We will use the following variables:
# * `list_items`: A list of numbers from 0 to 49 that we will search through.
# * `marked_item`: A randomly selected number from the list that we will search for.
# * `number_queries`: A count of how many times we need to query the list to find the marked item.

# %% [markdown]
# ###### **Solution**

# %%
list_items = range(50)

marked_item = random.choice(list_items)
number_queries = 0
for item in list_items:

    number_queries = number_queries + 1

    if item == marked_item:
        print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break
# Out:
# 32 has been found in 33 queries.

# %% [markdown]
# #### **Problem #1.2**
#
# **Together**, let's complete the code below to run our linear search many times to find the *worst number of queries*. We will use the following additional variables:
# * `number_trials`: The number of times to repeat the linear search.
# * `worst_query`: The most number of queries we had to make across all trials.

# %% [markdown]
# ###### **Solution**

# %%
number_trials = 10
worst_query = 0
list_items = range(50)

for i in range(number_trials):

  marked_item = random.choice(list_items)
  number_queries = 0
  for item in list_items:

      number_queries = number_queries + 1

      if item == marked_item:
        print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

  worst_query = max(worst_query, number_queries)

print("Worst number of queries: " + str(worst_query))
# Out:
# 38 has been found in 39 queries.
# 21 has been found in 22 queries.
# 43 has been found in 44 queries.
# 12 has been found in 13 queries.
# 1 has been found in 2 queries.
# 27 has been found in 28 queries.
# 40 has been found in 41 queries.
# 23 has been found in 24 queries.
# 17 has been found in 18 queries.
# 19 has been found in 20 queries.
# Worst number of queries: 44

# %% [markdown]
# #### **Problem #1.3**
#
# **Together**, let's put this code into a function called `linear_search` such that it:
# * Takes `n` as input parameters.
# * Runs the code we wrote in Exercise #2 such that there are `n` items in `list_items`.
# * Returns the worst number of queries instead of printing it.

# %% [markdown]
# ###### **Solution**

# %%
def linear_search(n):

  number_trials = 10
  worst_query = 0
  list_items = range(n)

  for i in range(number_trials):

    marked_item = random.choice(list_items)
    number_queries = 0
    for item in list_items:

      number_queries = number_queries + 1

      if item == marked_item:
        #print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

    worst_query = max(worst_query, number_queries)

  return worst_query

# %% [markdown]
# ### **Problem #1.4**
#
# **Together**, let's graph the worst number of queries for list sizes from 100 to 10000.

# %% [markdown]
# ###### **Solution**

# %%
linear_queries = []
ns = range(100, 10000, 100)
for n in ns:
  linear_queries += [linear_search(n)]

plt.scatter(ns, linear_queries, label = "linear")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Linear Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()
# Out:
# []

# %% [markdown]
# <a name="p2"></a>
#
# ---
# ## **Part 2: Binary Search**
# ---
#
# In this section, we will implement and analyze the binary search algorithm. We will also visually compare it to the linear search algorithm we implemented above.

# %% [markdown]
# #### **Problem #2.1**
#
# **Together**, let's complete the code below to implement binary search for a list of numbers. We will use the following variables:
# * `list_items`: A list of numbers from 0 to 49 that we will search through.
# * `marked_item`: A randomly selected number from the list that we will search for.
# * `number_queries`: A count of how many times we need to query the list to find the marked item.

# %% [markdown]
# ###### **Solution**

# %%
list_items = range(50)
marked_item = random.choice(list_items)

left = 0
right = len(list_items) - 1

number_queries = 0
for item in list_items:

  number_queries = number_queries + 1

  middle = int((left + right)/2)
  if list_items[middle] > marked_item:
    right = middle
  elif list_items[middle] < marked_item:
    left = middle
  else:
    print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
    break
# Out:
# 26 has been found in 6 queries.

# %% [markdown]
# #### **Problem #2.2**
#
# **Independently**, complete the code below to run our binary search many times to find the *worst number of queries*. You will use the following additional variables:
# * `number_trials`: The number of times to repeat the binary search.
# * `worst_query`: The most number of queries we had to make across all trials.

# %% [markdown]
# ###### **Solution**

# %%
number_trials = 10
worst_query = 0
list_items = range(50)

for i in range(number_trials):

  marked_item = random.choice(list_items)

  left = 0
  right = len(list_items) - 1

  number_queries = 0
  for item in list_items:

    number_queries = number_queries + 1

    middle = int((left + right)/2)
    if list_items[middle] > marked_item:
      right = middle
    elif list_items[middle] < marked_item:
      left = middle
    else:
      print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
      break

  worst_query = max(worst_query, number_queries)

print("Worst number of queries: " + str(worst_query))
# Out:
# 20 has been found in 6 queries.
# 33 has been found in 4 queries.
# 27 has been found in 4 queries.
# 18 has been found in 3 queries.
# 10 has been found in 5 queries.
# 29 has been found in 6 queries.
# 43 has been found in 5 queries.
# 12 has been found in 2 queries.
# 26 has been found in 6 queries.
# 2 has been found in 6 queries.
# Worst number of queries: 6

# %% [markdown]
# #### **Problem #2.3**
#
# **Independently**, put this code into a function called `binary_search` such that it:
# * Takes `n` as input parameters.
# * Runs the code we wrote in Exercise #2 such that there are `n` items in `list_items`.
# * Returns the worst number of queries instead of printing it.

# %% [markdown]
# ###### **Solution**

# %%
def binary_search(n):

  number_trials = 10
  worst_query = 0
  list_items = range(n)

  for i in range(number_trials):

    marked_item = random.choice(list_items)

    left = 0
    right = len(list_items) - 1

    number_queries = 0
    for item in list_items:

      number_queries = number_queries + 1

      middle = int((left + right)/2)
      if list_items[middle] > marked_item:
        right = middle
      elif list_items[middle] < marked_item:
        left = middle
      else:
        print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

    worst_query = max(worst_query, number_queries)

  return worst_query

# %% [markdown]
# ---
# ####**Wait for your instructor to continue.**
#
# ---

# %% [markdown]
# #### **Problem #2.4**
#
# **Together**, graph the worst number of queries for list sizes from 100 to 10000.

# %% [markdown]
# ###### **Solution**

# %%
# Importing  python libraries
import random
import matplotlib.pyplot as plt



binary_queries = []
ns = range(100, 10000, 100)
for n in ns:
  binary_queries += [binary_search(n)]

plt.scatter(ns, binary_queries, label = "binary")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Binary Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()
# Out:
# 68 has been found in 6 queries.
# 13 has been found in 6 queries.
# 92 has been found in 4 queries.
# 43 has been found in 6 queries.
# 40 has been found in 6 queries.
# 1 has been found in 6 queries.
# 37 has been found in 6 queries.
# 85 has been found in 7 queries.
# 41 has been found in 7 queries.
# 57 has been found in 7 queries.
# 171 has been found in 8 queries.
# 147 has been found in 7 queries.
# 78 has been found in 7 queries.
# 65 has been found in 7 queries.
# 146 has been found in 8 queries.
# 186 has been found in 4 queries.
# 194 has been found in 8 queries.
# 4 has been found in 7 queries.
# 10 has been found in 7 queries.
# 20 has been found in 8 queries.
# 178 has been found in 7 queries.
# 65 has been found in 8 queries.
# 256 has been found in 6 queries.
# 2 has been found in 7 queries.
# 148 has been found in 9 queries.
# 84 has been found in 8 queries.
# 166 has been found in 9 queries.
# 189 has been found in 8 queries.
# 283 has been found in 8 queries.
# 79 has been found in 8 queries.
# 329 has been found in 9 queries.
# 149 has been found in 3 queries.
# 217 has been found in 6 queries.
# 8 has been found in 9 queries.
# 228 has been found in 8 queries.
# 256 has been found in 8 queries.
# 249 has been found in 3 queries.
# 87 has been found in 8 queries.
# 382 has been found in 9 queries.
# 386 has been found in 5 queries.
# 456 has been found in 9 queries.
# 226 has been found in 9 queries.
# 189 has been found in 7 queries.
# 396 has been found in 9 queries.
# 75 has been found in 8 queries.
# 190 has been found in 9 queries.
# 240 has been found in 9 queries.
# 107 has been found in 9 queries.
# 12 has been found in 9 queries.
# 182 has been found in 7 queries.
# 179 has been found in 9 queries.
# 132 has been found in 8 queries.
# 317 has been found in 5 queries.
# 369 has been found in 7 queries.
# 336 has been found in 4 queries.
# 204 has been found in 10 queries.
# 455 has been found in 8 queries.
# 281 has been found in 9 queries.
# 233 has been found in 6 queries.
# 110 has been found in 10 queries.
# 260 has been found in 10 queries.
# 661 has been found in 9 queries.
# 531 has been found in 8 queries.
# 158 has been found in 9 queries.
# 91 has been found in 10 queries.
# 146 has been found in 7 queries.
# 186 has been found in 8 queries.
# 8 has been found in 9 queries.
# 340 has been found in 8 queries.
# 101 has been found in 10 queries.
# 210 has been found in 10 queries.
# 453 has been found in 9 queries.
# 331 has been found in 9 queries.
# 786 has been found in 6 queries.
# 186 has been found in 6 queries.
# 685 has been found in 10 queries.
# 637 has been found in 9 queries.
# 410 has been found in 10 queries.
# 281 has been found in 9 queries.
# 317 has been found in 7 queries.
# 545 has been found in 9 queries.
# 232 has been found in 9 queries.
# 109 has been found in 10 queries.
# 100 has been found in 10 queries.
# 67 has been found in 10 queries.
# 186 has been found in 10 queries.
# 161 has been found in 7 queries.
# 629 has been found in 9 queries.
# 746 has been found in 10 queries.
# 2 has been found in 10 queries.
# 749 has been found in 2 queries.
# 758 has been found in 9 queries.
# 759 has been found in 10 queries.
# 955 has been found in 8 queries.
# 607 has been found in 10 queries.
# 60 has been found in 9 queries.
# 706 has been found in 10 queries.
# 127 has been found in 8 queries.
# 735 has been found in 9 queries.
# 647 has been found in 10 queries.
# 107 has been found in 10 queries.
# 1046 has been found in 11 queries.
# 617 has been found in 4 queries.
# 472 has been found in 10 queries.
# 872 has been found in 9 queries.
# 779 has been found in 10 queries.
# 228 has been found in 9 queries.
# 662 has been found in 10 queries.
# 253 has been found in 9 queries.
# 274 has been found in 11 queries.
# 472 has been found in 10 queries.
# 657 has been found in 9 queries.
# 984 has been found in 10 queries.
# 905 has been found in 9 queries.
# 564 has been found in 10 queries.
# 469 has been found in 9 queries.
# 87 has been found in 8 queries.
# 901 has been found in 9 queries.
# 365 has been found in 10 queries.
# 78 has been found in 9 queries.
# 1171 has been found in 8 queries.
# 394 has been found in 7 queries.
# 262 has been found in 11 queries.
# 1155 has been found in 11 queries.
# 1243 has been found in 10 queries.
# 739 has been found in 11 queries.
# 984 has been found in 7 queries.
# 258 has been found in 8 queries.
# 475 has been found in 7 queries.
# 831 has been found in 10 queries.
# 1392 has been found in 11 queries.
# 1034 has been found in 11 queries.
# 799 has been found in 9 queries.
# 982 has been found in 11 queries.
# 1355 has been found in 5 queries.
# 815 has been found in 11 queries.
# 205 has been found in 11 queries.
# 775 has been found in 7 queries.
# 639 has been found in 10 queries.
# 99 has been found in 10 queries.
# 728 has been found in 9 queries.
# 1290 has been found in 9 queries.
# 1302 has been found in 9 queries.
# 361 has been found in 11 queries.
# 845 has been found in 10 queries.
# 1474 has been found in 11 queries.
# 95 has been found in 9 queries.
# 348 has been found in 10 queries.
# 496 has been found in 8 queries.
# 1349 has been found in 5 queries.
# 664 has been found in 9 queries.
# 1555 has been found in 8 queries.
# 1577 has been found in 9 queries.
# 904 has been found in 11 queries.
# 206 has been found in 10 queries.
# 585 has been found in 11 queries.
# 884 has been found in 10 queries.
# 584 has been found in 10 queries.
# 655 has been found in 8 queries.
# 28 has been found in 11 queries.
# 916 has been found in 10 queries.
# 423 has been found in 11 queries.
# 459 has been found in 9 queries.
# 1606 has been found in 10 queries.
# 214 has been found in 11 queries.
# 487 has been found in 11 queries.
# 1416 has been found in 11 queries.
# 867 has been found in 11 queries.
# 899 has been found in 11 queries.
# 947 has been found in 11 queries.
# 1239 has been found in 9 queries.
# 1752 has been found in 9 queries.
# 42 has been found in 7 queries.
# 1279 has been found in 10 queries.
# 905 has been found in 11 queries.
# 1577 has been found in 9 queries.
# 1156 has been found in 11 queries.
# 1034 has been found in 11 queries.
# 1474 has been found in 11 queries.
# 648 has been found in 11 queries.
# 1593 has been found in 8 queries.
# 27 has been found in 10 queries.
# 1054 has been found in 11 queries.
# 178 has been found in 10 queries.
# 167 has been found in 10 queries.
# 382 has been found in 10 queries.
# 782 has been found in 11 queries.
# 938 has been found in 11 queries.
# 483 has been found in 11 queries.
# 610 has been found in 10 queries.
# 1992 has been found in 11 queries.
# 1530 has been found in 6 queries.
# 851 has been found in 11 queries.
# 408 has been found in 9 queries.
# 695 has been found in 10 queries.
# 1663 has been found in 11 queries.
# 781 has been found in 10 queries.
# 298 has been found in 11 queries.
# 1699 has been found in 10 queries.
# 156 has been found in 11 queries.
# 397 has been found in 9 queries.
# 1129 has been found in 11 queries.
# 488 has been found in 10 queries.
# 1675 has been found in 11 queries.
# 1084 has been found in 11 queries.
# 1329 has been found in 10 queries.
# 1162 has been found in 11 queries.
# 293 has been found in 11 queries.
# 1593 has been found in 11 queries.
# 875 has been found in 7 queries.
# 369 has been found in 10 queries.
# 2070 has been found in 11 queries.
# 332 has been found in 11 queries.
# 1101 has been found in 10 queries.
# 2160 has been found in 11 queries.
# 1190 has been found in 10 queries.
# 1237 has been found in 11 queries.
# 832 has been found in 8 queries.
# 951 has been found in 12 queries.
# 1950 has been found in 10 queries.
# 640 has been found in 9 queries.
# 83 has been found in 11 queries.
# 579 has been found in 11 queries.
# 1577 has been found in 10 queries.
# 1413 has been found in 9 queries.
# 211 has been found in 11 queries.
# 444 has been found in 11 queries.
# 597 has been found in 10 queries.
# 1170 has been found in 9 queries.
# 1113 has been found in 12 queries.
# 1117 has been found in 11 queries.
# 634 has been found in 11 queries.
# 1970 has been found in 11 queries.
# 2294 has been found in 12 queries.
# 612 has been found in 9 queries.
# 1773 has been found in 11 queries.
# 260 has been found in 12 queries.
# 1996 has been found in 11 queries.
# 549 has been found in 11 queries.
# 1548 has been found in 10 queries.
# 1719 has been found in 10 queries.
# 1786 has been found in 11 queries.
# 1140 has been found in 8 queries.
# 336 has been found in 9 queries.
# 811 has been found in 10 queries.
# 2098 has been found in 8 queries.
# 720 has been found in 12 queries.
# 99 has been found in 10 queries.
# 2004 has been found in 12 queries.
# 1270 has been found in 10 queries.
# 896 has been found in 12 queries.
# 2577 has been found in 12 queries.
# 1951 has been found in 10 queries.
# 2075 has been found in 9 queries.
# 1755 has been found in 8 queries.
# 26 has been found in 11 queries.
# 994 has been found in 7 queries.
# 2211 has been found in 12 queries.
# 684 has been found in 9 queries.
# 1920 has been found in 10 queries.
# 208 has been found in 11 queries.
# 200 has been found in 11 queries.
# 377 has been found in 11 queries.
# 903 has been found in 11 queries.
# 1245 has been found in 10 queries.
# 952 has been found in 9 queries.
# 1509 has been found in 11 queries.
# 2460 has been found in 9 queries.
# 899 has been found in 9 queries.
# 871 has been found in 10 queries.
# 281 has been found in 11 queries.
# 2380 has been found in 10 queries.
# 539 has been found in 9 queries.
# 1274 has been found in 12 queries.
# 557 has been found in 11 queries.
# 1653 has been found in 11 queries.
# 675 has been found in 11 queries.
# 2637 has been found in 11 queries.
# 232 has been found in 12 queries.
# 2018 has been found in 12 queries.
# 724 has been found in 2 queries.
# 532 has been found in 11 queries.
# 85 has been found in 11 queries.
# 2869 has been found in 12 queries.
# 2231 has been found in 11 queries.
# 1896 has been found in 11 queries.
# 136 has been found in 11 queries.
# 2862 has been found in 11 queries.
# 1817 has been found in 11 queries.
# 1894 has been found in 10 queries.
# 1097 has been found in 10 queries.
# 1671 has been found in 10 queries.
# 1930 has been found in 12 queries.
# 2576 has been found in 12 queries.
# 340 has been found in 12 queries.
# 2159 has been found in 12 queries.
# 1933 has been found in 12 queries.
# 1109 has been found in 10 queries.
# 611 has been found in 11 queries.
# 871 has been found in 11 queries.
# 1809 has been found in 11 queries.
# 1159 has been found in 11 queries.
# 1149 has been found in 11 queries.
# 2977 has been found in 7 queries.
# 526 has been found in 11 queries.
# 1259 has been found in 11 queries.
# 2836 has been found in 11 queries.
# 945 has been found in 10 queries.
# 2142 has been found in 8 queries.
# 2174 has been found in 7 queries.
# 1529 has been found in 12 queries.
# 1857 has been found in 12 queries.
# 1659 has been found in 11 queries.
# 2842 has been found in 9 queries.
# 3021 has been found in 12 queries.
# 2026 has been found in 12 queries.
# 2725 has been found in 11 queries.
# 155 has been found in 9 queries.
# 1770 has been found in 10 queries.
# 2072 has been found in 12 queries.
# 3176 has been found in 11 queries.
# 1976 has been found in 9 queries.
# 1176 has been found in 12 queries.
# 1767 has been found in 10 queries.
# 2799 has been found in 11 queries.
# 2708 has been found in 10 queries.
# 3012 has been found in 11 queries.
# 3092 has been found in 4 queries.
# 1730 has been found in 11 queries.
# 724 has been found in 10 queries.
# 3276 has been found in 11 queries.
# 806 has been found in 11 queries.
# 1010 has been found in 12 queries.
# 2897 has been found in 11 queries.
# 625 has been found in 10 queries.
# 1355 has been found in 12 queries.
# 1374 has been found in 11 queries.
# 294 has been found in 10 queries.
# 921 has been found in 9 queries.
# 3147 has been found in 11 queries.
# 3325 has been found in 11 queries.
# 3191 has been found in 11 queries.
# 616 has been found in 10 queries.
# 3273 has been found in 9 queries.
# 2372 has been found in 12 queries.
# 3249 has been found in 12 queries.
# 2164 has been found in 12 queries.
# 2810 has been found in 10 queries.
# 2384 has been found in 9 queries.
# 2886 has been found in 11 queries.
# 888 has been found in 12 queries.
# 3074 has been found in 10 queries.
# 2414 has been found in 12 queries.
# 1302 has been found in 10 queries.
# 1183 has been found in 10 queries.
# 3238 has been found in 11 queries.
# 628 has been found in 12 queries.
# 2885 has been found in 12 queries.
# 2682 has been found in 11 queries.
# 1377 has been found in 12 queries.
# 3496 has been found in 7 queries.
# 1098 has been found in 11 queries.
# 17 has been found in 10 queries.
# 3617 has been found in 11 queries.
# 3632 has been found in 12 queries.
# 2135 has been found in 11 queries.
# 2513 has been found in 7 queries.
# 1261 has been found in 12 queries.
# 741 has been found in 12 queries.
# 3135 has been found in 11 queries.
# 980 has been found in 12 queries.
# 2103 has been found in 12 queries.
# 357 has been found in 12 queries.
# 470 has been found in 10 queries.
# 720 has been found in 12 queries.
# 2892 has been found in 12 queries.
# 2510 has been found in 12 queries.
# 463 has been found in 12 queries.
# 1986 has been found in 12 queries.
# 1232 has been found in 8 queries.
# 1154 has been found in 11 queries.
# 3354 has been found in 12 queries.
# 2835 has been found in 10 queries.
# 1679 has been found in 11 queries.
# 1895 has been found in 9 queries.
# 2515 has been found in 10 queries.
# 1030 has been found in 10 queries.
# 1245 has been found in 11 queries.
# 3524 has been found in 12 queries.
# 2600 has been found in 9 queries.
# 2959 has been found in 9 queries.
# 619 has been found in 12 queries.
# 3175 has been found in 12 queries.
# 1838 has been found in 10 queries.
# 912 has been found in 9 queries.
# 1858 has been found in 8 queries.
# 1024 has been found in 11 queries.
# 3733 has been found in 8 queries.
# 2609 has been found in 12 queries.
# 2644 has been found in 12 queries.
# 150 has been found in 11 queries.
# 1281 has been found in 12 queries.
# 3390 has been found in 10 queries.
# 11 has been found in 12 queries.
# 1426 has been found in 11 queries.
# 1696 has been found in 7 queries.
# 1249 has been found in 12 queries.
# 91 has been found in 12 queries.
# 3734 has been found in 10 queries.
# 722 has been found in 11 queries.
# 1073 has been found in 9 queries.
# 2342 has been found in 11 queries.
# 3581 has been found in 11 queries.
# 3285 has been found in 12 queries.
# 1096 has been found in 12 queries.
# 2286 has been found in 9 queries.
# 3796 has been found in 9 queries.
# 2121 has been found in 11 queries.
# 3443 has been found in 7 queries.
# 1140 has been found in 13 queries.
# 1786 has been found in 9 queries.
# 3846 has been found in 11 queries.
# 2776 has been found in 12 queries.
# 720 has been found in 13 queries.
# 2576 has been found in 12 queries.
# 774 has been found in 12 queries.
# 280 has been found in 10 queries.
# 2388 has been found in 12 queries.
# 3983 has been found in 10 queries.
# 2627 has been found in 13 queries.
# 357 has been found in 12 queries.
# 26 has been found in 12 queries.
# 783 has been found in 12 queries.
# 179 has been found in 9 queries.
# 2434 has been found in 10 queries.
# 646 has been found in 10 queries.
# 2003 has been found in 12 queries.
# 204 has been found in 13 queries.
# 3832 has been found in 12 queries.
# 4244 has been found in 12 queries.
# 4141 has been found in 10 queries.
# 4363 has been found in 12 queries.
# 1357 has been found in 11 queries.
# 4333 has been found in 11 queries.
# 1661 has been found in 11 queries.
# 4416 has been found in 11 queries.
# 1084 has been found in 12 queries.
# 4090 has been found in 11 queries.
# 2991 has been found in 12 queries.
# 405 has been found in 11 queries.
# 641 has been found in 12 queries.
# 3581 has been found in 12 queries.
# 3081 has been found in 12 queries.
# 3098 has been found in 9 queries.
# 1082 has been found in 12 queries.
# 4222 has been found in 12 queries.
# 205 has been found in 13 queries.
# 1270 has been found in 12 queries.
# 303 has been found in 13 queries.
# 1904 has been found in 12 queries.
# 3269 has been found in 12 queries.
# 2868 has been found in 11 queries.
# 2021 has been found in 12 queries.
# 4599 has been found in 11 queries.
# 1268 has been found in 12 queries.
# 3193 has been found in 7 queries.
# 3697 has been found in 9 queries.
# 854 has been found in 11 queries.
# 3113 has been found in 12 queries.
# 1209 has been found in 12 queries.
# 189 has been found in 12 queries.
# 2341 has been found in 13 queries.
# 4741 has been found in 13 queries.
# 4441 has been found in 13 queries.
# 2107 has been found in 13 queries.
# 3842 has been found in 8 queries.
# 1253 has been found in 12 queries.
# 1866 has been found in 11 queries.
# 568 has been found in 12 queries.
# 847 has been found in 11 queries.
# 4725 has been found in 8 queries.
# 4544 has been found in 12 queries.
# 598 has been found in 12 queries.
# 47 has been found in 9 queries.
# 1729 has been found in 13 queries.
# 2027 has been found in 7 queries.
# 3575 has been found in 12 queries.
# 4523 has been found in 13 queries.
# 1250 has been found in 12 queries.
# 3341 has been found in 12 queries.
# 2821 has been found in 12 queries.
# 1985 has been found in 13 queries.
# 1264 has been found in 12 queries.
# 4951 has been found in 11 queries.
# 1012 has been found in 12 queries.
# 3541 has been found in 12 queries.
# 2328 has been found in 12 queries.
# 2270 has been found in 11 queries.
# 2372 has been found in 12 queries.
# 1765 has been found in 13 queries.
# 1619 has been found in 12 queries.
# 4878 has been found in 13 queries.
# 3650 has been found in 12 queries.
# 2434 has been found in 10 queries.
# 2173 has been found in 12 queries.
# 1283 has been found in 9 queries.
# 4664 has been found in 13 queries.
# 2574 has been found in 12 queries.
# 2756 has been found in 13 queries.
# 2091 has been found in 12 queries.
# 4731 has been found in 8 queries.
# 2579 has been found in 12 queries.
# 720 has been found in 12 queries.
# 3227 has been found in 13 queries.
# 2479 has been found in 12 queries.
# 4554 has been found in 10 queries.
# 4082 has been found in 12 queries.
# 857 has been found in 12 queries.
# 805 has been found in 10 queries.
# 3919 has been found in 12 queries.
# 4462 has been found in 12 queries.
# 4969 has been found in 11 queries.
# 1472 has been found in 13 queries.
# 60 has been found in 13 queries.
# 4944 has been found in 12 queries.
# 4274 has been found in 12 queries.
# 3629 has been found in 12 queries.
# 2239 has been found in 10 queries.
# 1463 has been found in 12 queries.
# 4463 has been found in 13 queries.
# 5390 has been found in 11 queries.
# 1220 has been found in 12 queries.
# 2024 has been found in 3 queries.
# 243 has been found in 11 queries.
# 4801 has been found in 13 queries.
# 2258 has been found in 12 queries.
# 3440 has been found in 12 queries.
# 4722 has been found in 12 queries.
# 1158 has been found in 8 queries.
# 3811 has been found in 13 queries.
# 5145 has been found in 12 queries.
# 1629 has been found in 12 queries.
# 4978 has been found in 12 queries.
# 409 has been found in 11 queries.
# 2207 has been found in 13 queries.
# 3370 has been found in 13 queries.
# 973 has been found in 11 queries.
# 2721 has been found in 10 queries.
# 3228 has been found in 11 queries.
# 4501 has been found in 13 queries.
# 565 has been found in 12 queries.
# 4312 has been found in 13 queries.
# 4186 has been found in 12 queries.
# 3460 has been found in 10 queries.
# 422 has been found in 11 queries.
# 374 has been found in 13 queries.
# 4239 has been found in 11 queries.
# 858 has been found in 12 queries.
# 643 has been found in 13 queries.
# 3093 has been found in 8 queries.
# 2977 has been found in 12 queries.
# 5251 has been found in 12 queries.
# 393 has been found in 13 queries.
# 2247 has been found in 8 queries.
# 4035 has been found in 13 queries.
# 3832 has been found in 13 queries.
# 4381 has been found in 13 queries.
# 2656 has been found in 12 queries.
# 3557 has been found in 13 queries.
# 5606 has been found in 12 queries.
# 1772 has been found in 13 queries.
# 5520 has been found in 10 queries.
# 3350 has been found in 13 queries.
# 2644 has been found in 13 queries.
# 4268 has been found in 13 queries.
# 2397 has been found in 11 queries.
# 198 has been found in 12 queries.
# 3463 has been found in 13 queries.
# 268 has been found in 11 queries.
# 2676 has been found in 13 queries.
# 3402 has been found in 13 queries.
# 3853 has been found in 12 queries.
# 5814 has been found in 11 queries.
# 3710 has been found in 12 queries.
# 1254 has been found in 9 queries.
# 1456 has been found in 10 queries.
# 5595 has been found in 13 queries.
# 4590 has been found in 10 queries.
# 2730 has been found in 12 queries.
# 3861 has been found in 13 queries.
# 1168 has been found in 12 queries.
# 61 has been found in 12 queries.
# 1344 has been found in 12 queries.
# 722 has been found in 11 queries.
# 1470 has been found in 12 queries.
# 3392 has been found in 12 queries.
# 4365 has been found in 13 queries.
# 5049 has been found in 9 queries.
# 5751 has been found in 13 queries.
# 6006 has been found in 11 queries.
# 1244 has been found in 12 queries.
# 1139 has been found in 13 queries.
# 3997 has been found in 13 queries.
# 463 has been found in 13 queries.
# 4319 has been found in 13 queries.
# 3348 has been found in 13 queries.
# 5135 has been found in 13 queries.
# 852 has been found in 12 queries.
# 1189 has been found in 13 queries.
# 4492 has been found in 12 queries.
# 964 has been found in 13 queries.
# 2988 has been found in 13 queries.
# 154 has been found in 12 queries.
# 4134 has been found in 12 queries.
# 5369 has been found in 10 queries.
# 3022 has been found in 13 queries.
# 4428 has been found in 12 queries.
# 4889 has been found in 13 queries.
# 5069 has been found in 11 queries.
# 2622 has been found in 11 queries.
# 299 has been found in 13 queries.
# 5201 has been found in 13 queries.
# 3541 has been found in 13 queries.
# 5565 has been found in 13 queries.
# 4971 has been found in 13 queries.
# 6264 has been found in 11 queries.
# 4767 has been found in 12 queries.
# 4501 has been found in 13 queries.
# 3306 has been found in 12 queries.
# 4578 has been found in 12 queries.
# 2039 has been found in 11 queries.
# 4314 has been found in 11 queries.
# 5521 has been found in 13 queries.
# 392 has been found in 10 queries.
# 4209 has been found in 12 queries.
# 5101 has been found in 13 queries.
# 4315 has been found in 12 queries.
# 4774 has been found in 8 queries.
# 59 has been found in 12 queries.
# 1987 has been found in 13 queries.
# 4330 has been found in 12 queries.
# 2626 has been found in 9 queries.
# 2879 has been found in 9 queries.
# 2152 has been found in 11 queries.
# 266 has been found in 12 queries.
# 5981 has been found in 12 queries.
# 3078 has been found in 13 queries.
# 139 has been found in 9 queries.
# 1539 has been found in 13 queries.
# 5529 has been found in 12 queries.
# 2189 has been found in 8 queries.
# 4682 has been found in 13 queries.
# 194 has been found in 12 queries.
# 5821 has been found in 11 queries.
# 1868 has been found in 12 queries.
# 4895 has been found in 12 queries.
# 5277 has been found in 12 queries.
# 633 has been found in 11 queries.
# 1198 has been found in 12 queries.
# 2207 has been found in 12 queries.
# 1964 has been found in 11 queries.
# 861 has been found in 12 queries.
# 396 has been found in 13 queries.
# 1403 has been found in 13 queries.
# 437 has been found in 10 queries.
# 5690 has been found in 9 queries.
# 1504 has been found in 12 queries.
# 1688 has been found in 12 queries.
# 2216 has been found in 12 queries.
# 4636 has been found in 11 queries.
# 5452 has been found in 11 queries.
# 478 has been found in 12 queries.
# 1396 has been found in 11 queries.
# 6080 has been found in 13 queries.
# 6487 has been found in 12 queries.
# 2418 has been found in 11 queries.
# 6154 has been found in 10 queries.
# 5420 has been found in 11 queries.
# 5530 has been found in 10 queries.
# 1535 has been found in 8 queries.
# 1258 has been found in 13 queries.
# 3283 has been found in 11 queries.
# 666 has been found in 10 queries.
# 1636 has been found in 10 queries.
# 1106 has been found in 13 queries.
# 335 has been found in 13 queries.
# 5530 has been found in 10 queries.
# 4708 has been found in 10 queries.
# 3751 has been found in 10 queries.
# 5598 has been found in 13 queries.
# 3336 has been found in 13 queries.
# 2085 has been found in 11 queries.
# 756 has been found in 13 queries.
# 3601 has been found in 10 queries.
# 3403 has been found in 12 queries.
# 4300 has been found in 13 queries.
# 4221 has been found in 13 queries.
# 1309 has been found in 12 queries.
# 5181 has been found in 12 queries.
# 3433 has been found in 13 queries.
# 2286 has been found in 9 queries.
# 5011 has been found in 10 queries.
# 405 has been found in 13 queries.
# 895 has been found in 13 queries.
# 6256 has been found in 13 queries.
# 822 has been found in 12 queries.
# 3474 has been found in 13 queries.
# 3180 has been found in 13 queries.
# 5173 has been found in 13 queries.
# 6711 has been found in 12 queries.
# 76 has been found in 13 queries.
# 4236 has been found in 12 queries.
# 3657 has been found in 13 queries.
# 5765 has been found in 12 queries.
# 7153 has been found in 13 queries.
# 2337 has been found in 13 queries.
# 2048 has been found in 11 queries.
# 4723 has been found in 13 queries.
# 2734 has been found in 10 queries.
# 3975 has been found in 13 queries.
# 6844 has been found in 13 queries.
# 5001 has been found in 13 queries.
# 7091 has been found in 10 queries.
# 2470 has been found in 12 queries.
# 6767 has been found in 13 queries.
# 4906 has been found in 11 queries.
# 3022 has been found in 12 queries.
# 5534 has been found in 11 queries.
# 1631 has been found in 10 queries.
# 4842 has been found in 13 queries.
# 1136 has been found in 11 queries.
# 6376 has been found in 13 queries.
# 7376 has been found in 13 queries.
# 7153 has been found in 12 queries.
# 1739 has been found in 13 queries.
# 6341 has been found in 12 queries.
# 4433 has been found in 12 queries.
# 6347 has been found in 13 queries.
# 4933 has been found in 10 queries.
# 6785 has been found in 12 queries.
# 7355 has been found in 13 queries.
# 6030 has been found in 13 queries.
# 6541 has been found in 13 queries.
# 6536 has been found in 12 queries.
# 1851 has been found in 10 queries.
# 646 has been found in 11 queries.
# 512 has been found in 12 queries.
# 5155 has been found in 4 queries.
# 1777 has been found in 10 queries.
# 6157 has been found in 12 queries.
# 7351 has been found in 12 queries.
# 2297 has been found in 12 queries.
# 4145 has been found in 12 queries.
# 81 has been found in 13 queries.
# 3470 has been found in 13 queries.
# 5058 has been found in 12 queries.
# 4694 has been found in 12 queries.
# 5465 has been found in 13 queries.
# 6687 has been found in 12 queries.
# 665 has been found in 13 queries.
# 5059 has been found in 13 queries.
# 6915 has been found in 13 queries.
# 7437 has been found in 13 queries.
# 7199 has been found in 12 queries.
# 2141 has been found in 10 queries.
# 280 has been found in 13 queries.
# 3831 has been found in 12 queries.
# 2401 has been found in 11 queries.
# 5634 has been found in 11 queries.
# 4960 has been found in 11 queries.
# 1930 has been found in 13 queries.
# 3941 has been found in 13 queries.
# 2868 has been found in 12 queries.
# 4826 has been found in 12 queries.
# 6997 has been found in 13 queries.
# 5148 has been found in 12 queries.
# 4526 has been found in 11 queries.
# 6865 has been found in 11 queries.
# 7133 has been found in 12 queries.
# 6019 has been found in 11 queries.
# 713 has been found in 13 queries.
# 7782 has been found in 10 queries.
# 7212 has been found in 13 queries.
# 2299 has been found in 13 queries.
# 2403 has been found in 12 queries.
# 1641 has been found in 10 queries.
# 2651 has been found in 13 queries.
# 3790 has been found in 11 queries.
# 479 has been found in 12 queries.
# 3549 has been found in 11 queries.
# 892 has been found in 13 queries.
# 4089 has been found in 13 queries.
# 7026 has been found in 11 queries.
# 298 has been found in 13 queries.
# 7170 has been found in 9 queries.
# 1499 has been found in 4 queries.
# 5635 has been found in 11 queries.
# 6229 has been found in 11 queries.
# 7471 has been found in 11 queries.
# 5590 has been found in 10 queries.
# 7127 has been found in 12 queries.
# 7226 has been found in 13 queries.
# 1701 has been found in 12 queries.
# 3219 has been found in 12 queries.
# 7051 has been found in 13 queries.
# 2693 has been found in 12 queries.
# 109 has been found in 13 queries.
# 3417 has been found in 13 queries.
# 4884 has been found in 12 queries.
# 7810 has been found in 11 queries.
# 2859 has been found in 12 queries.
# 7889 has been found in 13 queries.
# 7575 has been found in 13 queries.
# 197 has been found in 13 queries.
# 4240 has been found in 13 queries.
# 6929 has been found in 11 queries.
# 4135 has been found in 11 queries.
# 4782 has been found in 13 queries.
# 6309 has been found in 8 queries.
# 7712 has been found in 12 queries.
# 4420 has been found in 11 queries.
# 4051 has been found in 8 queries.
# 718 has been found in 12 queries.
# 1200 has been found in 12 queries.
# 2804 has been found in 12 queries.
# 3312 has been found in 13 queries.
# 6717 has been found in 10 queries.
# 2971 has been found in 13 queries.
# 1540 has been found in 12 queries.
# 5003 has been found in 13 queries.
# 5650 has been found in 10 queries.
# 3988 has been found in 11 queries.
# 1332 has been found in 13 queries.
# 1163 has been found in 9 queries.
# 4898 has been found in 13 queries.
# 1069 has been found in 11 queries.
# 5272 has been found in 13 queries.
# 51 has been found in 13 queries.
# 6676 has been found in 13 queries.
# 6874 has been found in 13 queries.
# 3146 has been found in 13 queries.
# 5067 has been found in 12 queries.
# 7806 has been found in 12 queries.
# 2495 has been found in 13 queries.
# 3166 has been found in 12 queries.
# 1406 has been found in 13 queries.
# 6366 has been found in 13 queries.
# 1089 has been found in 13 queries.
# 1496 has been found in 13 queries.
# 2542 has been found in 10 queries.
# 2640 has been found in 13 queries.
# 3879 has been found in 13 queries.
# 5359 has been found in 12 queries.
# 5860 has been found in 9 queries.
# 4612 has been found in 11 queries.
# 91 has been found in 10 queries.
# 5869 has been found in 13 queries.
# 5054 has been found in 9 queries.
# 7813 has been found in 13 queries.
# 4025 has been found in 14 queries.
# 5458 has been found in 13 queries.
# 2748 has been found in 12 queries.
# 3525 has been found in 13 queries.
# 2610 has been found in 11 queries.
# 5653 has been found in 13 queries.
# 74 has been found in 13 queries.
# 5593 has been found in 11 queries.
# 2440 has been found in 11 queries.
# 7667 has been found in 13 queries.
# 60 has been found in 13 queries.
# 4765 has been found in 12 queries.
# 1845 has been found in 14 queries.
# 8565 has been found in 13 queries.
# 4711 has been found in 13 queries.
# 8398 has been found in 11 queries.
# 1706 has been found in 12 queries.
# 2587 has been found in 13 queries.
# 6299 has been found in 12 queries.
# 6985 has been found in 13 queries.
# 7349 has been found in 13 queries.
# 6821 has been found in 10 queries.
# 473 has been found in 13 queries.
# 2713 has been found in 13 queries.
# 3400 has been found in 11 queries.
# 3823 has been found in 13 queries.
# 6125 has been found in 10 queries.
# 8635 has been found in 13 queries.
# 7713 has been found in 12 queries.
# 3146 has been found in 12 queries.
# 8442 has been found in 12 queries.
# 3216 has been found in 13 queries.
# 3107 has been found in 13 queries.
# 7755 has been found in 13 queries.
# 8032 has been found in 13 queries.
# 7135 has been found in 8 queries.
# 7222 has been found in 9 queries.
# 785 has been found in 13 queries.
# 3217 has been found in 12 queries.
# 1945 has been found in 13 queries.
# 2963 has been found in 12 queries.
# 1609 has been found in 12 queries.
# 7048 has been found in 13 queries.
# 4320 has been found in 13 queries.
# 4238 has been found in 13 queries.
# 5459 has been found in 13 queries.
# 3 has been found in 13 queries.
# 8838 has been found in 13 queries.
# 4388 has been found in 9 queries.
# 1908 has been found in 14 queries.
# 8266 has been found in 12 queries.
# 7244 has been found in 11 queries.
# 5637 has been found in 13 queries.
# 3752 has been found in 13 queries.
# 5668 has been found in 10 queries.
# 6724 has been found in 13 queries.
# 9188 has been found in 13 queries.
# 59 has been found in 12 queries.
# 6567 has been found in 13 queries.
# 6845 has been found in 9 queries.
# 5101 has been found in 14 queries.
# 5609 has been found in 14 queries.
# 3476 has been found in 10 queries.
# 4781 has been found in 12 queries.
# 3597 has been found in 13 queries.
# 2926 has been found in 13 queries.
# 2855 has been found in 13 queries.
# 5122 has been found in 12 queries.
# 1577 has been found in 14 queries.
# 4107 has been found in 11 queries.
# 1513 has been found in 13 queries.
# 2798 has been found in 10 queries.
# 7744 has been found in 13 queries.
# 5965 has been found in 9 queries.
# 1523 has been found in 12 queries.
# 7692 has been found in 12 queries.
# 2748 has been found in 13 queries.
# 2769 has been found in 14 queries.
# 5372 has been found in 11 queries.
# 2003 has been found in 11 queries.
# 5893 has been found in 11 queries.
# 4886 has been found in 14 queries.
# 7532 has been found in 13 queries.
# 3233 has been found in 13 queries.
# 9007 has been found in 13 queries.
# 8978 has been found in 14 queries.
# 6490 has been found in 13 queries.
# 379 has been found in 10 queries.
# 6406 has been found in 13 queries.
# 1914 has been found in 13 queries.
# 6826 has been found in 12 queries.
# 3651 has been found in 13 queries.
# 2522 has been found in 12 queries.
# 8177 has been found in 13 queries.
# 548 has been found in 12 queries.
# 7643 has been found in 14 queries.
# 6195 has been found in 10 queries.
# 6652 has been found in 12 queries.
# 376 has been found in 12 queries.
# 7280 has been found in 12 queries.
# 3361 has been found in 13 queries.
# 1777 has been found in 12 queries.
# 3708 has been found in 12 queries.
# 822 has been found in 14 queries.
# 9229 has been found in 13 queries.
# 6229 has been found in 13 queries.
# 725 has been found in 12 queries.
# 5172 has been found in 12 queries.
# 2328 has been found in 14 queries.
# 4698 has been found in 13 queries.
# 2734 has been found in 14 queries.
# 3464 has been found in 12 queries.
# 3903 has been found in 7 queries.
# 3462 has been found in 9 queries.
# 6203 has been found in 13 queries.
# 6263 has been found in 13 queries.
# 9029 has been found in 13 queries.
# 8375 has been found in 14 queries.
# 6422 has been found in 12 queries.
# 2804 has been found in 12 queries.
# 4013 has been found in 13 queries.
# 759 has been found in 12 queries.
# 8506 has been found in 6 queries.
# 7130 has been found in 12 queries.
# 9381 has been found in 13 queries.
# 7418 has been found in 14 queries.
# 8948 has been found in 13 queries.
# 5881 has been found in 13 queries.
# 6929 has been found in 10 queries.
# 5472 has been found in 13 queries.
# []

# %% [markdown]
# #### **Problem #2.5**
#
# **Together**, let's graph the worst number of queries for list sizes from 100 to 10000 *for both linear and binary search*.

# %% [markdown]
# ###### **Solution**

# %%
linear_queries = []
binary_queries = []
ns = range(100, 10000, 100)
for n in ns:
  linear_queries += [linear_search(n)]
  binary_queries += [binary_search(n)]

plt.scatter(ns, linear_queries, label = "linear")
plt.scatter(ns, binary_queries, label = "binary")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Linear and Binary Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()
# Out:
# 73 has been found in 7 queries.
# 7 has been found in 6 queries.
# 41 has been found in 7 queries.
# 50 has been found in 6 queries.
# 58 has been found in 5 queries.
# 52 has been found in 5 queries.
# 82 has been found in 7 queries.
# 98 has been found in 7 queries.
# 26 has been found in 7 queries.
# 69 has been found in 7 queries.
# 161 has been found in 4 queries.
# 176 has been found in 8 queries.
# 54 has been found in 8 queries.
# 190 has been found in 7 queries.
# 81 has been found in 7 queries.
# 156 has been found in 7 queries.
# 132 has been found in 8 queries.
# 61 has been found in 4 queries.
# 107 has been found in 8 queries.
# 105 has been found in 5 queries.
# 237 has been found in 6 queries.
# 37 has been found in 3 queries.
# 225 has been found in 8 queries.
# 226 has been found in 7 queries.
# 130 has been found in 4 queries.
# 159 has been found in 8 queries.
# 94 has been found in 7 queries.
# 190 has been found in 6 queries.
# 192 has been found in 7 queries.
# 177 has been found in 8 queries.
# 392 has been found in 6 queries.
# 353 has been found in 8 queries.
# 218 has been found in 8 queries.
# 62 has been found in 8 queries.
# 161 has been found in 5 queries.
# 59 has been found in 8 queries.
# 81 has been found in 8 queries.
# 367 has been found in 6 queries.
# 57 has been found in 9 queries.
# 281 has been found in 8 queries.
# 491 has been found in 6 queries.
# 253 has been found in 9 queries.
# 123 has been found in 9 queries.
# 51 has been found in 9 queries.
# 151 has been found in 7 queries.
# 302 has been found in 9 queries.
# 116 has been found in 6 queries.
# 308 has been found in 9 queries.
# 12 has been found in 9 queries.
# 334 has been found in 6 queries.
# 474 has been found in 9 queries.
# 461 has been found in 9 queries.
# 36 has been found in 10 queries.
# 210 has been found in 9 queries.
# 272 has been found in 8 queries.
# 73 has been found in 10 queries.
# 300 has been found in 9 queries.
# 438 has been found in 10 queries.
# 577 has been found in 8 queries.
# 141 has been found in 8 queries.
# 67 has been found in 8 queries.
# 458 has been found in 5 queries.
# 674 has been found in 8 queries.
# 334 has been found in 10 queries.
# 421 has been found in 10 queries.
# 665 has been found in 10 queries.
# 251 has been found in 9 queries.
# 256 has been found in 9 queries.
# 197 has been found in 8 queries.
# 29 has been found in 8 queries.
# 798 has been found in 10 queries.
# 221 has been found in 10 queries.
# 24 has been found in 5 queries.
# 739 has been found in 8 queries.
# 696 has been found in 10 queries.
# 437 has been found in 9 queries.
# 341 has been found in 10 queries.
# 334 has been found in 9 queries.
# 264 has been found in 8 queries.
# 505 has been found in 7 queries.
# 648 has been found in 8 queries.
# 436 has been found in 10 queries.
# 474 has been found in 10 queries.
# 45 has been found in 8 queries.
# 342 has been found in 10 queries.
# 230 has been found in 10 queries.
# 804 has been found in 10 queries.
# 799 has been found in 10 queries.
# 486 has been found in 10 queries.
# 380 has been found in 10 queries.
# 707 has been found in 9 queries.
# 683 has been found in 10 queries.
# 527 has been found in 10 queries.
# 114 has been found in 9 queries.
# 397 has been found in 7 queries.
# 904 has been found in 10 queries.
# 647 has been found in 7 queries.
# 478 has been found in 10 queries.
# 542 has been found in 10 queries.
# 20 has been found in 10 queries.
# 860 has been found in 9 queries.
# 458 has been found in 10 queries.
# 755 has been found in 4 queries.
# 66 has been found in 10 queries.
# 214 has been found in 10 queries.
# 665 has been found in 9 queries.
# 679 has been found in 9 queries.
# 1095 has been found in 10 queries.
# 793 has been found in 8 queries.
# 124 has been found in 10 queries.
# 487 has been found in 10 queries.
# 928 has been found in 9 queries.
# 72 has been found in 10 queries.
# 1071 has been found in 8 queries.
# 826 has been found in 9 queries.
# 124 has been found in 11 queries.
# 323 has been found in 9 queries.
# 17 has been found in 11 queries.
# 1031 has been found in 10 queries.
# 575 has been found in 8 queries.
# 514 has been found in 10 queries.
# 565 has been found in 10 queries.
# 200 has been found in 10 queries.
# 735 has been found in 8 queries.
# 121 has been found in 5 queries.
# 860 has been found in 11 queries.
# 169 has been found in 9 queries.
# 43 has been found in 10 queries.
# 1244 has been found in 9 queries.
# 231 has been found in 11 queries.
# 1022 has been found in 10 queries.
# 1036 has been found in 10 queries.
# 884 has been found in 7 queries.
# 464 has been found in 10 queries.
# 1029 has been found in 9 queries.
# 936 has been found in 9 queries.
# 479 has been found in 11 queries.
# 1306 has been found in 10 queries.
# 966 has been found in 8 queries.
# 320 has been found in 11 queries.
# 893 has been found in 11 queries.
# 866 has been found in 10 queries.
# 1284 has been found in 9 queries.
# 822 has been found in 10 queries.
# 307 has been found in 10 queries.
# 1080 has been found in 10 queries.
# 1378 has been found in 9 queries.
# 1008 has been found in 11 queries.
# 866 has been found in 10 queries.
# 1163 has been found in 11 queries.
# 828 has been found in 10 queries.
# 1157 has been found in 11 queries.
# 1460 has been found in 11 queries.
# 1134 has been found in 10 queries.
# 137 has been found in 10 queries.
# 508 has been found in 9 queries.
# 1178 has been found in 10 queries.
# 844 has been found in 11 queries.
# 1506 has been found in 10 queries.
# 1340 has been found in 10 queries.
# 1459 has been found in 6 queries.
# 747 has been found in 11 queries.
# 698 has been found in 9 queries.
# 1186 has been found in 8 queries.
# 836 has been found in 10 queries.
# 1272 has been found in 10 queries.
# 370 has been found in 11 queries.
# 850 has been found in 10 queries.
# 854 has been found in 11 queries.
# 836 has been found in 10 queries.
# 1086 has been found in 10 queries.
# 824 has been found in 9 queries.
# 705 has been found in 9 queries.
# 1344 has been found in 11 queries.
# 1337 has been found in 9 queries.
# 1147 has been found in 11 queries.
# 559 has been found in 10 queries.
# 1312 has been found in 11 queries.
# 1687 has been found in 10 queries.
# 224 has been found in 3 queries.
# 649 has been found in 10 queries.
# 380 has been found in 9 queries.
# 851 has been found in 8 queries.
# 717 has been found in 11 queries.
# 1599 has been found in 10 queries.
# 1771 has been found in 11 queries.
# 661 has been found in 11 queries.
# 799 has been found in 11 queries.
# 829 has been found in 11 queries.
# 688 has been found in 8 queries.
# 509 has been found in 11 queries.
# 1019 has been found in 11 queries.
# 1646 has been found in 11 queries.
# 1397 has been found in 8 queries.
# 923 has been found in 11 queries.
# 821 has been found in 11 queries.
# 945 has been found in 10 queries.
# 1857 has been found in 11 queries.
# 1514 has been found in 7 queries.
# 1176 has been found in 10 queries.
# 964 has been found in 10 queries.
# 959 has been found in 11 queries.
# 1658 has been found in 11 queries.
# 1100 has been found in 11 queries.
# 1846 has been found in 10 queries.
# 229 has been found in 6 queries.
# 1899 has been found in 11 queries.
# 259 has been found in 10 queries.
# 707 has been found in 9 queries.
# 334 has been found in 11 queries.
# 445 has been found in 6 queries.
# 1503 has been found in 11 queries.
# 1185 has been found in 11 queries.
# 1571 has been found in 8 queries.
# 514 has been found in 6 queries.
# 1395 has been found in 9 queries.
# 377 has been found in 11 queries.
# 1138 has been found in 11 queries.
# 665 has been found in 10 queries.
# 1474 has been found in 11 queries.
# 1414 has been found in 11 queries.
# 1949 has been found in 11 queries.
# 1533 has been found in 11 queries.
# 426 has been found in 11 queries.
# 1281 has been found in 11 queries.
# 1452 has been found in 11 queries.
# 45 has been found in 11 queries.
# 441 has been found in 10 queries.
# 1367 has been found in 11 queries.
# 1751 has been found in 11 queries.
# 544 has been found in 10 queries.
# 661 has been found in 10 queries.
# 407 has been found in 11 queries.
# 1757 has been found in 11 queries.
# 591 has been found in 10 queries.
# 640 has been found in 9 queries.
# 1493 has been found in 12 queries.
# 1734 has been found in 11 queries.
# 275 has been found in 9 queries.
# 2397 has been found in 11 queries.
# 1954 has been found in 10 queries.
# 145 has been found in 12 queries.
# 1641 has been found in 10 queries.
# 107 has been found in 8 queries.
# 733 has been found in 10 queries.
# 2360 has been found in 12 queries.
# 386 has been found in 11 queries.
# 238 has been found in 9 queries.
# 101 has been found in 12 queries.
# 2002 has been found in 10 queries.
# 270 has been found in 10 queries.
# 1607 has been found in 12 queries.
# 1491 has been found in 8 queries.
# 2568 has been found in 8 queries.
# 2366 has been found in 11 queries.
# 748 has been found in 11 queries.
# 1036 has been found in 10 queries.
# 2084 has been found in 12 queries.
# 228 has been found in 11 queries.
# 1915 has been found in 10 queries.
# 632 has been found in 11 queries.
# 1422 has been found in 8 queries.
# 1282 has been found in 10 queries.
# 1631 has been found in 12 queries.
# 62 has been found in 12 queries.
# 1275 has been found in 11 queries.
# 99 has been found in 9 queries.
# 805 has been found in 9 queries.
# 615 has been found in 9 queries.
# 34 has been found in 11 queries.
# 2432 has been found in 9 queries.
# 2476 has been found in 11 queries.
# 1731 has been found in 12 queries.
# 2252 has been found in 7 queries.
# 1148 has been found in 11 queries.
# 694 has been found in 11 queries.
# 303 has been found in 11 queries.
# 430 has been found in 9 queries.
# 2048 has been found in 12 queries.
# 1507 has been found in 12 queries.
# 770 has been found in 11 queries.
# 2221 has been found in 10 queries.
# 2577 has been found in 12 queries.
# 623 has been found in 12 queries.
# 1975 has been found in 11 queries.
# 950 has been found in 6 queries.
# 2469 has been found in 10 queries.
# 2522 has been found in 11 queries.
# 1535 has been found in 12 queries.
# 2111 has been found in 11 queries.
# 628 has been found in 10 queries.
# 1257 has been found in 12 queries.
# 361 has been found in 12 queries.
# 712 has been found in 12 queries.
# 1076 has been found in 12 queries.
# 2072 has been found in 8 queries.
# 1493 has been found in 9 queries.
# 1574 has been found in 9 queries.
# 2244 has been found in 11 queries.
# 1102 has been found in 12 queries.
# 2060 has been found in 10 queries.
# 1079 has been found in 10 queries.
# 2350 has been found in 12 queries.
# 1984 has been found in 6 queries.
# 1819 has been found in 12 queries.
# 1174 has been found in 11 queries.
# 25 has been found in 11 queries.
# 2511 has been found in 11 queries.
# 1626 has been found in 12 queries.
# 2131 has been found in 11 queries.
# 2309 has been found in 11 queries.
# 1854 has been found in 12 queries.
# 1992 has been found in 9 queries.
# 1363 has been found in 12 queries.
# 897 has been found in 11 queries.
# 2318 has been found in 11 queries.
# 1193 has been found in 11 queries.
# 2415 has been found in 11 queries.
# 1072 has been found in 11 queries.
# 3001 has been found in 12 queries.
# 1696 has been found in 10 queries.
# 696 has been found in 11 queries.
# 1251 has been found in 10 queries.
# 1650 has been found in 11 queries.
# 2136 has been found in 11 queries.
# 2927 has been found in 10 queries.
# 614 has been found in 10 queries.
# 996 has been found in 12 queries.
# 3208 has been found in 8 queries.
# 3115 has been found in 11 queries.
# 1817 has been found in 12 queries.
# 599 has been found in 10 queries.
# 1730 has been found in 12 queries.
# 728 has been found in 8 queries.
# 610 has been found in 11 queries.
# 2836 has been found in 10 queries.
# 2708 has been found in 6 queries.
# 758 has been found in 10 queries.
# 3137 has been found in 11 queries.
# 2378 has been found in 10 queries.
# 591 has been found in 11 queries.
# 510 has been found in 12 queries.
# 512 has been found in 11 queries.
# 1961 has been found in 11 queries.
# 2572 has been found in 10 queries.
# 1350 has been found in 12 queries.
# 3361 has been found in 7 queries.
# 120 has been found in 11 queries.
# 1914 has been found in 12 queries.
# 3449 has been found in 12 queries.
# 2318 has been found in 12 queries.
# 3334 has been found in 10 queries.
# 3156 has been found in 9 queries.
# 2769 has been found in 8 queries.
# 362 has been found in 11 queries.
# 3337 has been found in 12 queries.
# 3277 has been found in 12 queries.
# 3417 has been found in 11 queries.
# 3011 has been found in 10 queries.
# 2512 has been found in 10 queries.
# 1274 has been found in 12 queries.
# 3273 has been found in 12 queries.
# 2348 has been found in 12 queries.
# 1861 has been found in 11 queries.
# 3233 has been found in 12 queries.
# 3465 has been found in 11 queries.
# 3656 has been found in 11 queries.
# 2332 has been found in 9 queries.
# 901 has been found in 12 queries.
# 1669 has been found in 11 queries.
# 582 has been found in 11 queries.
# 975 has been found in 12 queries.
# 2254 has been found in 12 queries.
# 1617 has been found in 11 queries.
# 2063 has been found in 12 queries.
# 3515 has been found in 12 queries.
# 1338 has been found in 12 queries.
# 2829 has been found in 12 queries.
# 3568 has been found in 9 queries.
# 2901 has been found in 12 queries.
# 1455 has been found in 11 queries.
# 3435 has been found in 11 queries.
# 3153 has been found in 11 queries.
# 2279 has been found in 10 queries.
# 2787 has been found in 12 queries.
# 1570 has been found in 12 queries.
# 1536 has been found in 12 queries.
# 2327 has been found in 11 queries.
# 2691 has been found in 10 queries.
# 2566 has been found in 12 queries.
# 1432 has been found in 10 queries.
# 1438 has been found in 12 queries.
# 1715 has been found in 11 queries.
# 2096 has been found in 10 queries.
# 1398 has been found in 12 queries.
# 3462 has been found in 12 queries.
# 368 has been found in 11 queries.
# 1490 has been found in 12 queries.
# 1756 has been found in 9 queries.
# 2325 has been found in 12 queries.
# 248 has been found in 9 queries.
# 1902 has been found in 11 queries.
# 437 has been found in 12 queries.
# 193 has been found in 12 queries.
# 272 has been found in 8 queries.
# 447 has been found in 12 queries.
# 2852 has been found in 12 queries.
# 2974 has been found in 12 queries.
# 136 has been found in 9 queries.
# 1149 has been found in 12 queries.
# 2521 has been found in 12 queries.
# 966 has been found in 8 queries.
# 2171 has been found in 12 queries.
# 1760 has been found in 12 queries.
# 3982 has been found in 11 queries.
# 3375 has been found in 11 queries.
# 3266 has been found in 12 queries.
# 1936 has been found in 11 queries.
# 2327 has been found in 13 queries.
# 2831 has been found in 12 queries.
# 322 has been found in 10 queries.
# 2496 has been found in 10 queries.
# 1784 has been found in 11 queries.
# 766 has been found in 10 queries.
# 2868 has been found in 12 queries.
# 53 has been found in 12 queries.
# 644 has been found in 12 queries.
# 1746 has been found in 12 queries.
# 394 has been found in 12 queries.
# 3790 has been found in 12 queries.
# 1050 has been found in 12 queries.
# 2218 has been found in 11 queries.
# 3739 has been found in 12 queries.
# 3572 has been found in 12 queries.
# 222 has been found in 8 queries.
# 711 has been found in 9 queries.
# 1072 has been found in 9 queries.
# 60 has been found in 12 queries.
# 3315 has been found in 13 queries.
# 4129 has been found in 12 queries.
# 3912 has been found in 12 queries.
# 2436 has been found in 10 queries.
# 1472 has been found in 11 queries.
# 3527 has been found in 12 queries.
# 2913 has been found in 11 queries.
# 1415 has been found in 11 queries.
# 998 has been found in 12 queries.
# 1357 has been found in 11 queries.
# 4134 has been found in 11 queries.
# 3568 has been found in 11 queries.
# 1533 has been found in 12 queries.
# 3272 has been found in 12 queries.
# 1740 has been found in 13 queries.
# 4037 has been found in 12 queries.
# 4516 has been found in 12 queries.
# 4507 has been found in 12 queries.
# 13 has been found in 12 queries.
# 2170 has been found in 11 queries.
# 1666 has been found in 12 queries.
# 2797 has been found in 10 queries.
# 4034 has been found in 11 queries.
# 2613 has been found in 13 queries.
# 2775 has been found in 12 queries.
# 2063 has been found in 13 queries.
# 2284 has been found in 9 queries.
# 658 has been found in 12 queries.
# 2486 has been found in 12 queries.
# 932 has been found in 12 queries.
# 3903 has been found in 10 queries.
# 1328 has been found in 13 queries.
# 3590 has been found in 12 queries.
# 3672 has been found in 12 queries.
# 2177 has been found in 12 queries.
# 43 has been found in 11 queries.
# 1679 has been found in 12 queries.
# 2309 has been found in 10 queries.
# 453 has been found in 10 queries.
# 4021 has been found in 12 queries.
# 3487 has been found in 12 queries.
# 2855 has been found in 11 queries.
# 2388 has been found in 11 queries.
# 3369 has been found in 11 queries.
# 994 has been found in 6 queries.
# 4185 has been found in 10 queries.
# 3285 has been found in 10 queries.
# 4840 has been found in 13 queries.
# 3954 has been found in 13 queries.
# 75 has been found in 13 queries.
# 2735 has been found in 8 queries.
# 1365 has been found in 12 queries.
# 1028 has been found in 10 queries.
# 4946 has been found in 11 queries.
# 3620 has been found in 13 queries.
# 2044 has been found in 10 queries.
# 1176 has been found in 11 queries.
# 4616 has been found in 13 queries.
# 3943 has been found in 13 queries.
# 2855 has been found in 12 queries.
# 3101 has been found in 11 queries.
# 986 has been found in 11 queries.
# 3615 has been found in 12 queries.
# 4088 has been found in 12 queries.
# 3782 has been found in 12 queries.
# 867 has been found in 11 queries.
# 334 has been found in 11 queries.
# 3260 has been found in 10 queries.
# 3843 has been found in 8 queries.
# 4410 has been found in 13 queries.
# 450 has been found in 12 queries.
# 2956 has been found in 9 queries.
# 3373 has been found in 12 queries.
# 4289 has been found in 10 queries.
# 4970 has been found in 10 queries.
# 1051 has been found in 13 queries.
# 3340 has been found in 9 queries.
# 4860 has been found in 11 queries.
# 4287 has been found in 12 queries.
# 3620 has been found in 12 queries.
# 3264 has been found in 10 queries.
# 1884 has been found in 11 queries.
# 4920 has been found in 12 queries.
# 930 has been found in 8 queries.
# 5195 has been found in 8 queries.
# 2313 has been found in 13 queries.
# 3826 has been found in 12 queries.
# 4949 has been found in 12 queries.
# 5040 has been found in 12 queries.
# 1555 has been found in 13 queries.
# 2429 has been found in 13 queries.
# 2672 has been found in 12 queries.
# 2677 has been found in 8 queries.
# 1107 has been found in 11 queries.
# 3807 has been found in 11 queries.
# 3546 has been found in 13 queries.
# 1764 has been found in 10 queries.
# 3763 has been found in 9 queries.
# 5359 has been found in 12 queries.
# 1958 has been found in 12 queries.
# 818 has been found in 11 queries.
# 4869 has been found in 12 queries.
# 988 has been found in 12 queries.
# 3334 has been found in 12 queries.
# 2225 has been found in 12 queries.
# 5269 has been found in 13 queries.
# 174 has been found in 12 queries.
# 413 has been found in 12 queries.
# 3777 has been found in 11 queries.
# 49 has been found in 11 queries.
# 3308 has been found in 12 queries.
# 3478 has been found in 13 queries.
# 5049 has been found in 11 queries.
# 1510 has been found in 11 queries.
# 2141 has been found in 13 queries.
# 3472 has been found in 12 queries.
# 4966 has been found in 11 queries.
# 3561 has been found in 11 queries.
# 5289 has been found in 11 queries.
# 1941 has been found in 13 queries.
# 4338 has been found in 11 queries.
# 3001 has been found in 12 queries.
# 2242 has been found in 12 queries.
# 3328 has been found in 12 queries.
# 2146 has been found in 13 queries.
# 3523 has been found in 13 queries.
# 2326 has been found in 12 queries.
# 3624 has been found in 11 queries.
# 4494 has been found in 12 queries.
# 2409 has been found in 12 queries.
# 4950 has been found in 12 queries.
# 2735 has been found in 13 queries.
# 4815 has been found in 12 queries.
# 2785 has been found in 8 queries.
# 5073 has been found in 13 queries.
# 2767 has been found in 10 queries.
# 323 has been found in 13 queries.
# 937 has been found in 13 queries.
# 3795 has been found in 13 queries.
# 4489 has been found in 10 queries.
# 2215 has been found in 13 queries.
# 5180 has been found in 10 queries.
# 2459 has been found in 12 queries.
# 409 has been found in 12 queries.
# 5033 has been found in 9 queries.
# 5639 has been found in 10 queries.
# 4897 has been found in 13 queries.
# 1416 has been found in 12 queries.
# 1912 has been found in 12 queries.
# 1953 has been found in 13 queries.
# 4235 has been found in 13 queries.
# 1031 has been found in 12 queries.
# 2933 has been found in 13 queries.
# 556 has been found in 12 queries.
# 2415 has been found in 11 queries.
# 3629 has been found in 12 queries.
# 1744 has been found in 9 queries.
# 3605 has been found in 11 queries.
# 2824 has been found in 13 queries.
# 1337 has been found in 11 queries.
# 1660 has been found in 12 queries.
# 4703 has been found in 10 queries.
# 1520 has been found in 13 queries.
# 3630 has been found in 13 queries.
# 527 has been found in 12 queries.
# 2323 has been found in 13 queries.
# 2743 has been found in 13 queries.
# 395 has been found in 11 queries.
# 4355 has been found in 13 queries.
# 5031 has been found in 13 queries.
# 2832 has been found in 12 queries.
# 2794 has been found in 13 queries.
# 3847 has been found in 12 queries.
# 6103 has been found in 12 queries.
# 2616 has been found in 13 queries.
# 607 has been found in 11 queries.
# 1163 has been found in 13 queries.
# 3931 has been found in 11 queries.
# 5312 has been found in 12 queries.
# 3952 has been found in 10 queries.
# 4143 has been found in 12 queries.
# 3055 has been found in 13 queries.
# 1365 has been found in 12 queries.
# 204 has been found in 13 queries.
# 617 has been found in 11 queries.
# 2223 has been found in 12 queries.
# 4900 has been found in 13 queries.
# 1866 has been found in 12 queries.
# 3918 has been found in 12 queries.
# 2176 has been found in 9 queries.
# 5356 has been found in 10 queries.
# 4880 has been found in 11 queries.
# 851 has been found in 13 queries.
# 3031 has been found in 12 queries.
# 5227 has been found in 11 queries.
# 2349 has been found in 7 queries.
# 532 has been found in 13 queries.
# 1453 has been found in 12 queries.
# 1317 has been found in 10 queries.
# 3151 has been found in 13 queries.
# 6169 has been found in 13 queries.
# 5298 has been found in 13 queries.
# 2358 has been found in 13 queries.
# 2536 has been found in 13 queries.
# 2705 has been found in 12 queries.
# 2661 has been found in 13 queries.
# 3764 has been found in 13 queries.
# 2595 has been found in 12 queries.
# 5404 has been found in 12 queries.
# 3528 has been found in 12 queries.
# 2550 has been found in 12 queries.
# 3115 has been found in 12 queries.
# 4963 has been found in 13 queries.
# 6262 has been found in 13 queries.
# 4423 has been found in 11 queries.
# 5789 has been found in 11 queries.
# 6580 has been found in 12 queries.
# 688 has been found in 10 queries.
# 147 has been found in 10 queries.
# 1355 has been found in 12 queries.
# 87 has been found in 13 queries.
# 6320 has been found in 10 queries.
# 4637 has been found in 10 queries.
# 730 has been found in 12 queries.
# 1397 has been found in 13 queries.
# 1928 has been found in 10 queries.
# 3670 has been found in 13 queries.
# 1601 has been found in 10 queries.
# 5559 has been found in 9 queries.
# 5108 has been found in 10 queries.
# 4903 has been found in 12 queries.
# 1265 has been found in 13 queries.
# 4146 has been found in 12 queries.
# 4539 has been found in 13 queries.
# 3467 has been found in 13 queries.
# 3107 has been found in 12 queries.
# 4885 has been found in 13 queries.
# 3526 has been found in 13 queries.
# 979 has been found in 12 queries.
# 1244 has been found in 13 queries.
# 6232 has been found in 13 queries.
# 5545 has been found in 13 queries.
# 3465 has been found in 11 queries.
# 3799 has been found in 8 queries.
# 6570 has been found in 13 queries.
# 3031 has been found in 12 queries.
# 1577 has been found in 13 queries.
# 992 has been found in 11 queries.
# 2728 has been found in 13 queries.
# 697 has been found in 13 queries.
# 3561 has been found in 13 queries.
# 5631 has been found in 8 queries.
# 4010 has been found in 10 queries.
# 2217 has been found in 12 queries.
# 5570 has been found in 12 queries.
# 460 has been found in 11 queries.
# 1913 has been found in 12 queries.
# 3023 has been found in 13 queries.
# 1756 has been found in 12 queries.
# 1198 has been found in 13 queries.
# 6021 has been found in 12 queries.
# 2168 has been found in 11 queries.
# 3547 has been found in 12 queries.
# 5378 has been found in 13 queries.
# 421 has been found in 13 queries.
# 4650 has been found in 13 queries.
# 2854 has been found in 13 queries.
# 4576 has been found in 13 queries.
# 2949 has been found in 13 queries.
# 3879 has been found in 12 queries.
# 2455 has been found in 11 queries.
# 2308 has been found in 12 queries.
# 1214 has been found in 13 queries.
# 2443 has been found in 12 queries.
# 4284 has been found in 11 queries.
# 4294 has been found in 13 queries.
# 1357 has been found in 12 queries.
# 4370 has been found in 12 queries.
# 4202 has been found in 13 queries.
# 6503 has been found in 12 queries.
# 4099 has been found in 12 queries.
# 3969 has been found in 12 queries.
# 4647 has been found in 12 queries.
# 755 has been found in 9 queries.
# 1810 has been found in 12 queries.
# 5050 has been found in 12 queries.
# 2455 has been found in 13 queries.
# 298 has been found in 13 queries.
# 1718 has been found in 12 queries.
# 6159 has been found in 12 queries.
# 6646 has been found in 13 queries.
# 7076 has been found in 13 queries.
# 4018 has been found in 13 queries.
# 243 has been found in 12 queries.
# 5863 has been found in 13 queries.
# 7211 has been found in 12 queries.
# 271 has been found in 12 queries.
# 1678 has been found in 11 queries.
# 6198 has been found in 9 queries.
# 5309 has been found in 10 queries.
# 1766 has been found in 13 queries.
# 1917 has been found in 13 queries.
# 7161 has been found in 9 queries.
# 3099 has been found in 11 queries.
# 7119 has been found in 13 queries.
# 7322 has been found in 7 queries.
# 1866 has been found in 10 queries.
# 6637 has been found in 13 queries.
# 1262 has been found in 13 queries.
# 6160 has been found in 11 queries.
# 5401 has been found in 12 queries.
# 4348 has been found in 9 queries.
# 5279 has been found in 11 queries.
# 1323 has been found in 13 queries.
# 1308 has been found in 11 queries.
# 4720 has been found in 12 queries.
# 1382 has been found in 11 queries.
# 6890 has been found in 13 queries.
# 6957 has been found in 13 queries.
# 3093 has been found in 10 queries.
# 2709 has been found in 12 queries.
# 4962 has been found in 13 queries.
# 1753 has been found in 13 queries.
# 883 has been found in 13 queries.
# 5042 has been found in 13 queries.
# 3231 has been found in 9 queries.
# 1562 has been found in 13 queries.
# 7162 has been found in 13 queries.
# 4128 has been found in 12 queries.
# 2393 has been found in 11 queries.
# 2288 has been found in 13 queries.
# 7653 has been found in 9 queries.
# 1281 has been found in 11 queries.
# 6818 has been found in 12 queries.
# 1259 has been found in 13 queries.
# 6952 has been found in 10 queries.
# 6726 has been found in 12 queries.
# 6539 has been found in 12 queries.
# 4935 has been found in 12 queries.
# 4181 has been found in 12 queries.
# 1790 has been found in 12 queries.
# 2538 has been found in 11 queries.
# 736 has been found in 11 queries.
# 1332 has been found in 10 queries.
# 1514 has been found in 13 queries.
# 5806 has been found in 13 queries.
# 3543 has been found in 11 queries.
# 6209 has been found in 12 queries.
# 1385 has been found in 12 queries.
# 6827 has been found in 12 queries.
# 2014 has been found in 13 queries.
# 1699 has been found in 11 queries.
# 3311 has been found in 7 queries.
# 5643 has been found in 11 queries.
# 1145 has been found in 12 queries.
# 2837 has been found in 13 queries.
# 5480 has been found in 13 queries.
# 7668 has been found in 12 queries.
# 7958 has been found in 13 queries.
# 71 has been found in 12 queries.
# 5672 has been found in 12 queries.
# 6335 has been found in 13 queries.
# 3879 has been found in 13 queries.
# 7654 has been found in 13 queries.
# 623 has been found in 13 queries.
# 5769 has been found in 13 queries.
# 3962 has been found in 13 queries.
# 3223 has been found in 12 queries.
# 393 has been found in 13 queries.
# 2316 has been found in 10 queries.
# 682 has been found in 13 queries.
# 7433 has been found in 8 queries.
# 3137 has been found in 13 queries.
# 8090 has been found in 11 queries.
# 3713 has been found in 13 queries.
# 3687 has been found in 13 queries.
# 2316 has been found in 13 queries.
# 7727 has been found in 13 queries.
# 2308 has been found in 13 queries.
# 5877 has been found in 13 queries.
# 1552 has been found in 9 queries.
# 6148 has been found in 14 queries.
# 5443 has been found in 13 queries.
# 7507 has been found in 11 queries.
# 6211 has been found in 11 queries.
# 1849 has been found in 13 queries.
# 6620 has been found in 10 queries.
# 7670 has been found in 11 queries.
# 3163 has been found in 11 queries.
# 3748 has been found in 12 queries.
# 3755 has been found in 13 queries.
# 418 has been found in 12 queries.
# 2145 has been found in 12 queries.
# 1292 has been found in 12 queries.
# 7128 has been found in 12 queries.
# 5704 has been found in 13 queries.
# 5310 has been found in 13 queries.
# 6521 has been found in 12 queries.
# 5651 has been found in 13 queries.
# 1116 has been found in 12 queries.
# 2753 has been found in 13 queries.
# 2965 has been found in 12 queries.
# 5147 has been found in 13 queries.
# 2442 has been found in 11 queries.
# 138 has been found in 12 queries.
# 7299 has been found in 13 queries.
# 5287 has been found in 12 queries.
# 4288 has been found in 12 queries.
# 5091 has been found in 13 queries.
# 707 has been found in 13 queries.
# 5771 has been found in 13 queries.
# 123 has been found in 10 queries.
# 4224 has been found in 12 queries.
# 6196 has been found in 9 queries.
# 5932 has been found in 13 queries.
# 8535 has been found in 11 queries.
# 2615 has been found in 12 queries.
# 3979 has been found in 9 queries.
# 5831 has been found in 13 queries.
# 6195 has been found in 13 queries.
# 5233 has been found in 13 queries.
# 1705 has been found in 13 queries.
# 6873 has been found in 12 queries.
# 6826 has been found in 12 queries.
# 7539 has been found in 13 queries.
# 2557 has been found in 12 queries.
# 7998 has been found in 13 queries.
# 4618 has been found in 13 queries.
# 1535 has been found in 13 queries.
# 6006 has been found in 13 queries.
# 648 has been found in 13 queries.
# 4724 has been found in 12 queries.
# 3290 has been found in 10 queries.
# 4611 has been found in 12 queries.
# 6160 has been found in 13 queries.
# 4265 has been found in 11 queries.
# 4902 has been found in 13 queries.
# 5030 has been found in 13 queries.
# 3784 has been found in 11 queries.
# 6843 has been found in 11 queries.
# 7664 has been found in 8 queries.
# 642 has been found in 10 queries.
# 881 has been found in 13 queries.
# 8664 has been found in 12 queries.
# 8563 has been found in 13 queries.
# 4229 has been found in 14 queries.
# 1407 has been found in 9 queries.
# 3502 has been found in 12 queries.
# 7779 has been found in 12 queries.
# 5557 has been found in 13 queries.
# 308 has been found in 13 queries.
# 6260 has been found in 11 queries.
# 3608 has been found in 13 queries.
# 6384 has been found in 12 queries.
# 4138 has been found in 13 queries.
# 8510 has been found in 11 queries.
# 2997 has been found in 13 queries.
# 7242 has been found in 12 queries.
# 1049 has been found in 13 queries.
# 2455 has been found in 13 queries.
# 5760 has been found in 13 queries.
# 4575 has been found in 12 queries.
# 575 has been found in 13 queries.
# 7333 has been found in 11 queries.
# 731 has been found in 11 queries.
# 6974 has been found in 10 queries.
# 7513 has been found in 12 queries.
# 221 has been found in 10 queries.
# 7812 has been found in 13 queries.
# 5623 has been found in 10 queries.
# 2009 has been found in 13 queries.
# 3719 has been found in 13 queries.
# 7819 has been found in 11 queries.
# 6288 has been found in 8 queries.
# 8376 has been found in 11 queries.
# 8302 has been found in 12 queries.
# 1112 has been found in 14 queries.
# 6583 has been found in 14 queries.
# 2484 has been found in 12 queries.
# 5083 has been found in 14 queries.
# 3648 has been found in 12 queries.
# 2734 has been found in 11 queries.
# 2749 has been found in 10 queries.
# 9108 has been found in 13 queries.
# 6636 has been found in 14 queries.
# 4996 has been found in 13 queries.
# 1943 has been found in 13 queries.
# 5038 has been found in 10 queries.
# 6349 has been found in 13 queries.
# 9117 has been found in 13 queries.
# 7103 has been found in 13 queries.
# 3510 has been found in 12 queries.
# 7884 has been found in 13 queries.
# 3045 has been found in 14 queries.
# 140 has been found in 14 queries.
# 9032 has been found in 13 queries.
# 1330 has been found in 13 queries.
# 1336 has been found in 13 queries.
# 8810 has been found in 14 queries.
# 844 has been found in 13 queries.
# 1295 has been found in 13 queries.
# 4792 has been found in 12 queries.
# 9242 has been found in 13 queries.
# 2990 has been found in 13 queries.
# 1518 has been found in 13 queries.
# 1629 has been found in 13 queries.
# 7527 has been found in 13 queries.
# 4045 has been found in 12 queries.
# 2261 has been found in 14 queries.
# 3016 has been found in 13 queries.
# 8120 has been found in 11 queries.
# 2389 has been found in 12 queries.
# 786 has been found in 8 queries.
# 5315 has been found in 13 queries.
# 5762 has been found in 13 queries.
# 2498 has been found in 12 queries.
# 44 has been found in 13 queries.
# 2005 has been found in 9 queries.
# 4647 has been found in 13 queries.
# 5000 has been found in 11 queries.
# 6361 has been found in 12 queries.
# 6345 has been found in 10 queries.
# 3595 has been found in 12 queries.
# 7549 has been found in 13 queries.
# 9270 has been found in 14 queries.
# 5165 has been found in 11 queries.
# 4376 has been found in 12 queries.
# 2004 has been found in 12 queries.
# 6602 has been found in 12 queries.
# 7911 has been found in 14 queries.
# 1475 has been found in 13 queries.
# 1689 has been found in 11 queries.
# 184 has been found in 13 queries.
# 6047 has been found in 7 queries.
# 2509 has been found in 13 queries.
# 2270 has been found in 11 queries.
# 6795 has been found in 12 queries.
# 4050 has been found in 14 queries.
# 3006 has been found in 13 queries.
# 6193 has been found in 13 queries.
# 5698 has been found in 13 queries.
# 8446 has been found in 13 queries.
# 2916 has been found in 14 queries.
# 4968 has been found in 9 queries.
# 9626 has been found in 14 queries.
# 975 has been found in 13 queries.
# 5510 has been found in 12 queries.
# 3577 has been found in 12 queries.
# 4808 has been found in 11 queries.
# 3888 has been found in 11 queries.
# 9264 has been found in 14 queries.
# 9859 has been found in 14 queries.
# []

# %% [markdown]
# #### **Problem  #2.6**
#
# **Together**, let's see how the performance of binary and linear search change when the order of items in the list is random using the `random.sample(...)` function. We will do this in 3 steps:
#
# 1. Rewrite the `linear_search` function so that the list is randomly ordered.
# 2. Rewrite the `binary_search` function so that the list is randomly ordered.
# 3. Graph the average number of queries for both search algorithms.
#
# ---

# %% [markdown]
# ##### **Problem 2.6.1**
# Rewrite the `linear_search` function so that the list is randomly ordered.

# %% [markdown]
# ###### **Solution**

# %%
def linear_search(n):

  number_trials = 10
  worst_query = 0
  list_items = random.sample(range(n), n)

  for i in range(number_trials):

    marked_item = random.choice(list_items)
    number_queries = 0
    for item in list_items:

      number_queries = number_queries + 1

      if item == marked_item:
        #print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

    worst_query = max(worst_query, number_queries)

  return worst_query

# %% [markdown]
# ##### **Problem #2.6.2**
# Rewrite the `binary_search` function so that the list is randomly ordered.

# %% [markdown]
# ###### **Solution**

# %%
def binary_search(n):

  number_trials = 10
  worst_query = 0
  list_items = random.sample(range(n), n)

  for i in range(number_trials):

    marked_item = random.choice(list_items)

    left = 0
    right = len(list_items) - 1

    number_queries = 0
    for item in list_items:

      number_queries = number_queries + 1

      middle = int((left + right)/2)
      if list_items[middle] > marked_item:
        right = middle
      elif list_items[middle] < marked_item:
        left = middle
      else:
        #print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

    worst_query = max(worst_query, number_queries)

  return worst_query

# %% [markdown]
# ##### **Problem #2.6.3**
# Graph the average number of queries for both search algorithms.

# %% [markdown]
# ###### **Solution**

# %%
linear_queries = []

binary_queries = []

ns = range(100, 10000, 100)

for n in ns:
  linear_queries += [linear_search(n)]
  binary_queries += [binary_search(n)]

plt.scatter(ns, linear_queries, label = "linear")
plt.scatter(ns, binary_queries, label = "binary")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Linear and Binary Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()
# Out:
# []

# %% [markdown]
# #End of Lab
# ---
# © 2024 The Coding School, All rights reserved
